# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Andrew Dickinson**
# Current occupation: ROV Pilot
# Desired: Data Scientist

# %% [markdown]
# *I am interested in data science because it is at the forefront of every industry and computer technology. I'm particularly interested in the machine learning side of things and find it very exciting*

# %% [markdown]
# ### My code in the following cell should compute the basic sum "2+1"

# %%
2+1
# Out:
# 3

# %% [markdown]
# Examples of
# ___
# horizontal rule
# ***
#
# - Here is
# - a bulleted
# - list
#
#
# 1. This is a
# 2. numbered
# 3. list
#
#
# And | Heres a | Table
# ---|---|---
# 1|2|3
# 4|5|6
#
#
# [Hyperlink to Cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
#
# ![](data:image/jpeg;base64,... "A nice relevant image")
#
#
# ```Syntax Highlighting```
#
#
#   Below:
# > Is an
# > example of
# > blocked quotes
#
#
# and some ~~strikethrough~~
